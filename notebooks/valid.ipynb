# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ref = np.loadtxt("/work/hpc/spine-segmentation/outputs/dummy/dice_loss.txt")
score = np.loadtxt("/work/hpc/spine-segmentation/outputs/dummy/criterion.txt")

# %%
ref.shape
# Out:
# (238,)

# %%
i = 0
plt.plot(ref, label='Dice')
plt.plot(score, label='Criterion')
plt.legend()

# %%
score[0]
# Out:
# 0.9641085863113403
