# %%
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt
import os

# %%
data = sitk.ReadImage("/data/hpc/spine/dataset/spine_nii/images/83_t1.nii.gz")

# test = sitk.Flip(data, [False, False, True])

# %%
image = sitk.GetArrayFromImage(data)
print(image.shape)
plt.imshow(image[:,:,10], cmap="gray")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 image = sitk.GetArrayFromImage(data)
#       2 print(image.shape)
#       3 plt.imshow(image[:,:,10], cmap="gray")
#
# NameError: name 'sitk' is not defined

# %%
image = np.rollaxis(image, 2, 0)
image.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 image = np.rollaxis(image, 2, 0)
#       2 image.shape
#
# NameError: name 'np' is not defined

# %%
plt.imshow(image[:, :, 200])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 plt.imshow(image[:, :, 200])
#
# NameError: name 'plt' is not defined

# %%
print(data.GetSize()) 
print(data)
# Out:
# (32, 615, 367)
# Image (0x2587630)
#   RTTI typeinfo:   itk::Image<short, 3u>
#   Reference Count: 1
#   Modified Time: 1837
#   Debug: Off
#   Object Name:
#   Observers:
#     none
#   Source: (none)
#   Source output name: (none)
#   Release Data: Off
#   Data Released: False
#   Global Release Data: Off
#   PipelineMTime: 1812
#   UpdateMTime: 1833
#   RealTimeStamp: 0 seconds
#   LargestPossibleRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [32, 615, 367]
#   BufferedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [32, 615, 367]
#   RequestedRegion:
#     Dimension: 3
#     Index: [0, 0, 0]
#     Size: [32, 615, 367]
#   Spacing: [3.2961, 0.461304, 0.770839]
#   Origin: [-51.7295, -83.6991, -251.322]
#   Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   IndexToPointMatrix:
# 3.2961 0 0
# 0 0.461304 0
# 0 0 0.770839
#
#   PointToIndexMatrix:
# 0.303389 0 0
# 0 2.16777 0
# 0 0 1.29729
#
#   Inverse Direction:
# 1 0 0
# 0 1 0
# 0 0 1
#
#   PixelContainer:
# ...

# %%
print(data.GetSpacing())

# data.SetSpacing((1.5, 0.625, 0.5))
data.SetSpacing((0.5, 1.5, 2))

print(data.GetSpacing())
print(data.GetSize())
# Out:
# (3.337801456451416, 0.625, 0.37377050518989563)
# (0.5, 1.5, 2.0)
# (30, 448, 762)

# %%
def change_spacing(image, new_spacing, interpolator=sitk.sitkLinear):
    original_spacing = image.GetSpacing()
    original_size = image.GetSize()
    
    new_size = [int(round(osz * ospc / nspc)) for osz, ospc, nspc in zip(original_size, original_spacing, new_spacing)]
    new_size = tuple(new_size)
    
    resample = sitk.ResampleImageFilter()
    resample.SetOutputSpacing(new_spacing)
    resample.SetSize(new_size)
    resample.SetOutputDirection(image.GetDirection())
    resample.SetOutputOrigin(image.GetOrigin())
    resample.SetInterpolator(interpolator)
    
    return resample.Execute(image)

def get_new_size(original_spacing, original_size, new_spacing):
    new_size = [int(round(osz * ospc / nspc)) for osz, ospc, nspc in zip(original_size, original_spacing, new_spacing)]
    new_size = tuple(new_size)

    return new_size

def transpose_img(data, order):
    
    return sitk.PermuteAxes(data, order)

# %%
mask_path= "/data/hpc/spine/dataset/spine_nii/masks"
image_path = "/data/hpc/spine/dataset/spine_nii/images"
print(image_path)

img_name = []
voxel_space = []
voxel_size = []
num_vert = []
shapes = []
low_sig = []
high_sig = []

median_space = [3.30972338, 0.625, 0.58742571]  ##[0.5859375, 0.625, 0.66275334] ##[3.30972338, 0.625, 0.66275334]
for path in os.listdir(image_path):
    # if "SPACE" not in path:
    #     continue
    print(path)
    img_name.append(path)
    mask = sitk.ReadImage(os.path.join(mask_path, path))
    array = sitk.GetArrayFromImage(mask)
    space = mask.GetSpacing()
    o_size = mask.GetSize()
    voxel_space.append(space)
    voxel_size.append(array.shape)
    num_vert.append(np.max(array[array < 100]))

    array = sitk.GetArrayFromImage(sitk.ReadImage(os.path.join(image_path, path)))
    low_sig.append(np.quantile(array, 0.05))
    high_sig.append(np.quantile(array, 0.95))
    # voxel_size.append(change_spacing(data, median_space).GetSize())
# Out:
# /data/hpc/spine/dataset/spine_nii/images
# 88_t1.nii.gz
# 6_t2.nii.gz
# 45_t2_SPACE.nii.gz
# 152_t2.nii.gz
# 185_t1.nii.gz
# 253_t1.nii.gz
# 197_t2.nii.gz
# 140_t1.nii.gz
# 13_t1.nii.gz
# 241_t2.nii.gz
# 152_t2_SPACE.nii.gz
# 168_t1.nii.gz
# 65_t1.nii.gz
# 136_t1.nii.gz
# 237_t2.nii.gz
# 29_t2.nii.gz
# 124_t2.nii.gz
# 225_t1.nii.gz
# 252_t1.nii.gz
# 184_t1.nii.gz
# 7_t2.nii.gz
# 110_t2_SPACE.nii.gz
# 12_t1.nii.gz
# 196_t2.nii.gz
# 236_t2.nii.gz
# 137_t1.nii.gz
# 64_t1.nii.gz
# 169_t1.nii.gz
# 224_t1.nii.gz
# 125_t2.nii.gz
# 28_t2.nii.gz
# 195_t2.nii.gz
# 142_t1.nii.gz
# 11_t1.nii.gz
# 243_t2.nii.gz
# 98_t2.nii.gz
# 142_t2_SPACE.nii.gz
# 187_t1.nii.gz
# 251_t1.nii.gz
# 4_t2.nii.gz
# 5_t2_SPACE.nii.gz
# 75_t2.nii.gz
# 227_t1.nii.gz
# 55_t2_SPACE.nii.gz
# 67_t1.nii.gz
# 39_t1.nii.gz
# 99_t2.nii.gz
# 242_t2.nii.gz
# 10_t1.nii.gz
# 143_t1.nii.gz
# 5_t2.nii.gz
# 209_t2_SPACE.nii.gz
# 250_t1.nii.gz
# 186_t1.nii.gz
# 151_t2.nii.gz
# 179_t2.nii.gz
# 226_t1.nii.gz
# 74_t2.nii.gz
# ...

# %%
plt.close()
spaces = np.array(voxel_space)
low_sigs = np.array(low_sig)
high_sigs = np.array(high_sig)
sizes = np.array(voxel_size)
verts = np.array(num_vert)
print(np.median(spaces, axis=0), np.std(spaces, axis=0))
print(np.median(low_sigs), np.std(low_sigs))
print(np.median(high_sigs), np.std(high_sigs))
print(np.mean(sizes, axis=0), np.std(sizes, axis=0))
# plt.scatter(np.arange(low_sigs.shape[0]),verts)
print(np.max(sizes, axis=0))
plt.scatter(np.arange(low_sigs.shape[0]),sorted(high_sigs))
plt.scatter(np.arange(low_sigs.shape[0]),sorted(low_sigs))
# for i in range(3):
#     plt.scatter(np.arange(low_sigs.shape[0]),sorted(spaces[:, i]))
#     plt.scatter(np.arange(low_sigs.shape[0]),sorted(sizes[:, i]))


# plt.scatter(voxel_space, voxel_space)
# Out:
# [0.89999998 0.46875    0.46875   ] [0.01143151 0.00053874 0.02246365]
# 1.0 466.3848038335692
# 238.0 1347.4417821692762
# [647.09756098 511.92682927 123.31707317] [34.97790583  0.46277234  7.69364332]
# [793 512 154]

# %%
voxel_size = np.array(voxel_size)
np.set_printoptions(threshold=np.inf)

median_voxel_size = np.median(voxel_size, axis=0)
min_voxel_size = np.min(voxel_size, axis=0)


print(min_voxel_size)
print(median_voxel_size)
print(len(voxel_size))
print(voxel_size)
# Out:
# [ 32 384 409]
# [ 47. 448. 479.]
# 447
# [[ 60 456 481]
#  [ 49 448 480]
#  [ 51 448 480]
#  [ 53 496 527]
#  [ 51 448 481]
#  [ 62 480 409]
#  [ 40 448 478]
#  [ 44 416 445]
#  [ 45 448 477]
#  [ 45 448 477]
#  [ 45 448 477]
#  [ 38 480 513]
#  [ 51 448 481]
#  [ 64 457 485]
#  [ 56 448 485]
#  [ 51 449 480]
#  [ 52 416 449]
#  [ 36 480 511]
#  [ 32 480 511]
#  [ 32 480 511]
#  [ 36 480 511]
#  [ 63 448 488]
#  [ 64 423 452]
#  [ 47 416 443]
#  [ 62 480 409]
#  [ 41 448 477]
#  [ 32 480 511]
#  [ 47 448 478]
#  [ 65 384 515]
#  [ 32 480 511]
#  [ 49 448 479]
#  [ 36 480 511]
#  [ 45 493 526]
#  [ 45 448 477]
#  [ 38 448 477]
#  [ 55 496 530]
#  [ 79 448 492]
#  [ 51 450 478]
#  [ 32 480 511]
#  [ 55 493 526]
#  [ 36 480 511]
#  [ 60 454 482]
#  [ 43 448 477]
#  [ 47 480 511]
#  [ 41 448 477]
#  [ 36 480 511]
#  [ 53 497 526]
#  [ 40 448 478]
#  [ 49 448 477]
#  [ 32 480 511]
#  [ 38 480 512]
#  [ 47 448 478]
#  [ 47 448 478]
#  [ 62 480 409]
#  [ 43 448 481]
#  [ 62 480 409]
# ...

# %%
reverse_voxel = []

for voxel in voxel_size:
    if np.argmin(voxel) != 0:
        reverse_voxel.append(voxel)

reverse_voxel = np.array(reverse_voxel)
print(len(reverse_voxel))
print(reverse_voxel)
# Out:
# 0
# []

# %%
print(voxel_space)
# Out:
# [[4.8276186  0.8125     0.62789905]
#  [4.78167725 0.67708331 0.79624355]
#  [0.89999998 0.46875    0.46875   ]
#  ...
#  [4.39122534 0.60342926 0.41289261]
#  [3.28456092 0.60428977 0.71954304]
#  [3.30000019 0.5859375  0.5859375 ]]
